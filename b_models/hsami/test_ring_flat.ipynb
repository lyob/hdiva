# %%
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

notebook_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(notebook_dir, ".."))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
print(sys.path)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %load_ext autoreload
# %autoreload 2
# Out:
# ['/mnt/ceph/users/blyo1/projects', '/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python310.zip', '/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10', '/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/lib-dynload', '', '/mnt/home/blyo1/venvs/py310/lib/python3.10/site-packages']

# %% [markdown]
# # train

# %%
from b_models.hsami.sequential_training_ring import train
train()
# Out:
# device: cuda
# parameters: 416,396
# run dir: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313
# === Stage 1: denoiser_x unconditional (500 epochs) ===
# [stage1] epoch     0 | step       0 | loss 1.0129 | lr 0.00e+00
# [stage1] epoch    20 | step     100 | loss 1.0042 | lr 8.00e-05
# [stage1] epoch    40 | step     200 | loss 0.5802 | lr 1.60e-04
# [stage1] epoch    60 | step     300 | loss 0.5111 | lr 2.00e-04
# [stage1] epoch    80 | step     400 | loss 0.4685 | lr 1.98e-04
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage1_epoch_000100.pt
# [stage1] epoch   100 | step     500 | loss 0.4809 | lr 1.95e-04
# [stage1] epoch   120 | step     600 | loss 0.4672 | lr 1.89e-04
# [stage1] epoch   140 | step     700 | loss 0.4729 | lr 1.83e-04
# [stage1] epoch   160 | step     800 | loss 0.4584 | lr 1.75e-04
# [stage1] epoch   180 | step     900 | loss 0.4506 | lr 1.65e-04
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage1_epoch_000200.pt
# [stage1] epoch   200 | step    1000 | loss 0.4607 | lr 1.55e-04
# [stage1] epoch   220 | step    1100 | loss 0.4576 | lr 1.44e-04
# [stage1] epoch   240 | step    1200 | loss 0.4585 | lr 1.32e-04
# [stage1] epoch   260 | step    1300 | loss 0.4595 | lr 1.19e-04
# [stage1] epoch   280 | step    1400 | loss 0.4543 | lr 1.07e-04
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage1_epoch_000300.pt
# [stage1] epoch   300 | step    1500 | loss 0.4457 | lr 9.44e-05
# [stage1] epoch   320 | step    1600 | loss 0.4299 | lr 8.22e-05
# [stage1] epoch   340 | step    1700 | loss 0.4518 | lr 7.05e-05
# [stage1] epoch   360 | step    1800 | loss 0.4503 | lr 5.97e-05
# [stage1] epoch   380 | step    1900 | loss 0.4422 | lr 4.98e-05
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage1_epoch_000400.pt
# [stage1] epoch   400 | step    2000 | loss 0.4480 | lr 4.11e-05
# [stage1] epoch   420 | step    2100 | loss 0.4563 | lr 3.37e-05
# [stage1] epoch   440 | step    2200 | loss 0.4708 | lr 2.78e-05
# [stage1] epoch   460 | step    2300 | loss 0.4430 | lr 2.35e-05
# [stage1] epoch   480 | step    2400 | loss 0.4502 | lr 2.09e-05
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage1_epoch_000500.pt
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage1_epoch_000500.pt
# === Stage 1 complete ===
# === Stage 2: denoiser_x + x→y encoder (2000 epochs) ===
# [stage2] epoch     0 | step       0 | mse_x_guided 0.4436 | |s(xg)| 8.5954e-01 | |s(y|xg)| 2.3646e-02
# [stage2] epoch    20 | step     100 | mse_x_guided 0.4544 | |s(xg)| 8.1632e-01 | |s(y|xg)| 2.8238e-01
# [stage2] epoch    40 | step     200 | mse_x_guided 0.4427 | |s(xg)| 8.1827e-01 | |s(y|xg)| 3.1802e-01
# [stage2] epoch    60 | step     300 | mse_x_guided 0.4387 | |s(xg)| 8.1935e-01 | |s(y|xg)| 3.3378e-01
# [stage2] epoch    80 | step     400 | mse_x_guided 0.4518 | |s(xg)| 8.0345e-01 | |s(y|xg)| 3.1437e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000100.pt
# [stage2] epoch   100 | step     500 | mse_x_guided 0.4507 | |s(xg)| 8.1183e-01 | |s(y|xg)| 3.2156e-01
# [stage2] epoch   120 | step     600 | mse_x_guided 0.4559 | |s(xg)| 8.0184e-01 | |s(y|xg)| 3.2139e-01
# [stage2] epoch   140 | step     700 | mse_x_guided 0.4478 | |s(xg)| 8.1103e-01 | |s(y|xg)| 3.4412e-01
# [stage2] epoch   160 | step     800 | mse_x_guided 0.4543 | |s(xg)| 8.0697e-01 | |s(y|xg)| 3.2399e-01
# [stage2] epoch   180 | step     900 | mse_x_guided 0.4506 | |s(xg)| 8.2340e-01 | |s(y|xg)| 3.4668e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000200.pt
# [stage2] epoch   200 | step    1000 | mse_x_guided 0.4387 | |s(xg)| 8.3458e-01 | |s(y|xg)| 3.6055e-01
# [stage2] epoch   220 | step    1100 | mse_x_guided 0.4406 | |s(xg)| 8.0133e-01 | |s(y|xg)| 3.3052e-01
# [stage2] epoch   240 | step    1200 | mse_x_guided 0.4446 | |s(xg)| 8.1511e-01 | |s(y|xg)| 3.4663e-01
# [stage2] epoch   260 | step    1300 | mse_x_guided 0.4662 | |s(xg)| 8.1184e-01 | |s(y|xg)| 3.3364e-01
# [stage2] epoch   280 | step    1400 | mse_x_guided 0.4348 | |s(xg)| 8.3556e-01 | |s(y|xg)| 3.2690e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000300.pt
# [stage2] epoch   300 | step    1500 | mse_x_guided 0.4448 | |s(xg)| 8.2676e-01 | |s(y|xg)| 3.3391e-01
# [stage2] epoch   320 | step    1600 | mse_x_guided 0.4507 | |s(xg)| 8.4126e-01 | |s(y|xg)| 3.4683e-01
# [stage2] epoch   340 | step    1700 | mse_x_guided 0.4347 | |s(xg)| 8.1611e-01 | |s(y|xg)| 3.2940e-01
# [stage2] epoch   360 | step    1800 | mse_x_guided 0.4449 | |s(xg)| 8.2850e-01 | |s(y|xg)| 3.3038e-01
# [stage2] epoch   380 | step    1900 | mse_x_guided 0.4443 | |s(xg)| 8.2921e-01 | |s(y|xg)| 3.2865e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000400.pt
# [stage2] epoch   400 | step    2000 | mse_x_guided 0.4386 | |s(xg)| 8.3487e-01 | |s(y|xg)| 3.5320e-01
# [stage2] epoch   420 | step    2100 | mse_x_guided 0.4469 | |s(xg)| 8.1973e-01 | |s(y|xg)| 3.4308e-01
# [stage2] epoch   440 | step    2200 | mse_x_guided 0.4583 | |s(xg)| 8.0298e-01 | |s(y|xg)| 3.5696e-01
# [stage2] epoch   460 | step    2300 | mse_x_guided 0.4436 | |s(xg)| 8.2174e-01 | |s(y|xg)| 3.3425e-01
# [stage2] epoch   480 | step    2400 | mse_x_guided 0.4673 | |s(xg)| 8.2870e-01 | |s(y|xg)| 3.4314e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000500.pt
# [stage2] epoch   500 | step    2500 | mse_x_guided 0.4402 | |s(xg)| 8.2542e-01 | |s(y|xg)| 3.4843e-01
# [stage2] epoch   520 | step    2600 | mse_x_guided 0.4621 | |s(xg)| 8.1373e-01 | |s(y|xg)| 3.3404e-01
# [stage2] epoch   540 | step    2700 | mse_x_guided 0.4468 | |s(xg)| 8.3366e-01 | |s(y|xg)| 3.3487e-01
# [stage2] epoch   560 | step    2800 | mse_x_guided 0.4625 | |s(xg)| 8.0760e-01 | |s(y|xg)| 3.3425e-01
# [stage2] epoch   580 | step    2900 | mse_x_guided 0.4533 | |s(xg)| 8.3469e-01 | |s(y|xg)| 3.5619e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000600.pt
# [stage2] epoch   600 | step    3000 | mse_x_guided 0.4614 | |s(xg)| 8.1664e-01 | |s(y|xg)| 3.4215e-01
# [stage2] epoch   620 | step    3100 | mse_x_guided 0.4563 | |s(xg)| 8.2137e-01 | |s(y|xg)| 3.4469e-01
# [stage2] epoch   640 | step    3200 | mse_x_guided 0.4609 | |s(xg)| 8.1243e-01 | |s(y|xg)| 3.4187e-01
# [stage2] epoch   660 | step    3300 | mse_x_guided 0.4367 | |s(xg)| 8.0246e-01 | |s(y|xg)| 3.3231e-01
# [stage2] epoch   680 | step    3400 | mse_x_guided 0.4469 | |s(xg)| 8.2773e-01 | |s(y|xg)| 3.3971e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000700.pt
# [stage2] epoch   700 | step    3500 | mse_x_guided 0.4494 | |s(xg)| 8.2292e-01 | |s(y|xg)| 3.3754e-01
# [stage2] epoch   720 | step    3600 | mse_x_guided 0.4576 | |s(xg)| 8.3064e-01 | |s(y|xg)| 3.4144e-01
# [stage2] epoch   740 | step    3700 | mse_x_guided 0.4549 | |s(xg)| 8.2375e-01 | |s(y|xg)| 3.3321e-01
# [stage2] epoch   760 | step    3800 | mse_x_guided 0.4522 | |s(xg)| 8.0980e-01 | |s(y|xg)| 3.4246e-01
# [stage2] epoch   780 | step    3900 | mse_x_guided 0.4689 | |s(xg)| 8.2571e-01 | |s(y|xg)| 3.5718e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000800.pt
# [stage2] epoch   800 | step    4000 | mse_x_guided 0.4680 | |s(xg)| 8.2241e-01 | |s(y|xg)| 3.3097e-01
# [stage2] epoch   820 | step    4100 | mse_x_guided 0.4452 | |s(xg)| 8.3081e-01 | |s(y|xg)| 3.3399e-01
# [stage2] epoch   840 | step    4200 | mse_x_guided 0.4618 | |s(xg)| 8.1200e-01 | |s(y|xg)| 3.4580e-01
# [stage2] epoch   860 | step    4300 | mse_x_guided 0.4402 | |s(xg)| 8.1724e-01 | |s(y|xg)| 3.3998e-01
# [stage2] epoch   880 | step    4400 | mse_x_guided 0.4547 | |s(xg)| 8.2179e-01 | |s(y|xg)| 3.4578e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_000900.pt
# [stage2] epoch   900 | step    4500 | mse_x_guided 0.4399 | |s(xg)| 8.0332e-01 | |s(y|xg)| 3.4291e-01
# [stage2] epoch   920 | step    4600 | mse_x_guided 0.4427 | |s(xg)| 8.1452e-01 | |s(y|xg)| 3.4352e-01
# [stage2] epoch   940 | step    4700 | mse_x_guided 0.4443 | |s(xg)| 8.2214e-01 | |s(y|xg)| 3.5325e-01
# [stage2] epoch   960 | step    4800 | mse_x_guided 0.4470 | |s(xg)| 8.2941e-01 | |s(y|xg)| 3.2292e-01
# [stage2] epoch   980 | step    4900 | mse_x_guided 0.4577 | |s(xg)| 8.1751e-01 | |s(y|xg)| 3.3373e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001000.pt
# [stage2] epoch  1000 | step    5000 | mse_x_guided 0.4446 | |s(xg)| 8.1868e-01 | |s(y|xg)| 3.4649e-01
# [stage2] epoch  1020 | step    5100 | mse_x_guided 0.4437 | |s(xg)| 8.2117e-01 | |s(y|xg)| 3.3450e-01
# [stage2] epoch  1040 | step    5200 | mse_x_guided 0.4572 | |s(xg)| 8.3250e-01 | |s(y|xg)| 3.4624e-01
# [stage2] epoch  1060 | step    5300 | mse_x_guided 0.4445 | |s(xg)| 8.1118e-01 | |s(y|xg)| 3.6035e-01
# [stage2] epoch  1080 | step    5400 | mse_x_guided 0.4442 | |s(xg)| 8.2975e-01 | |s(y|xg)| 3.3335e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001100.pt
# [stage2] epoch  1100 | step    5500 | mse_x_guided 0.4542 | |s(xg)| 8.0412e-01 | |s(y|xg)| 3.2881e-01
# [stage2] epoch  1120 | step    5600 | mse_x_guided 0.4494 | |s(xg)| 8.2600e-01 | |s(y|xg)| 3.4692e-01
# [stage2] epoch  1140 | step    5700 | mse_x_guided 0.4521 | |s(xg)| 8.1661e-01 | |s(y|xg)| 3.4223e-01
# [stage2] epoch  1160 | step    5800 | mse_x_guided 0.4396 | |s(xg)| 8.0691e-01 | |s(y|xg)| 3.4890e-01
# [stage2] epoch  1180 | step    5900 | mse_x_guided 0.4548 | |s(xg)| 8.2855e-01 | |s(y|xg)| 3.3980e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001200.pt
# [stage2] epoch  1200 | step    6000 | mse_x_guided 0.4379 | |s(xg)| 8.2245e-01 | |s(y|xg)| 3.4841e-01
# [stage2] epoch  1220 | step    6100 | mse_x_guided 0.4452 | |s(xg)| 8.1336e-01 | |s(y|xg)| 3.3880e-01
# [stage2] epoch  1240 | step    6200 | mse_x_guided 0.4405 | |s(xg)| 8.3489e-01 | |s(y|xg)| 3.4656e-01
# [stage2] epoch  1260 | step    6300 | mse_x_guided 0.4381 | |s(xg)| 8.3142e-01 | |s(y|xg)| 3.4854e-01
# [stage2] epoch  1280 | step    6400 | mse_x_guided 0.4452 | |s(xg)| 8.2850e-01 | |s(y|xg)| 3.4534e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001300.pt
# [stage2] epoch  1300 | step    6500 | mse_x_guided 0.4461 | |s(xg)| 8.3640e-01 | |s(y|xg)| 3.4431e-01
# [stage2] epoch  1320 | step    6600 | mse_x_guided 0.4344 | |s(xg)| 8.2170e-01 | |s(y|xg)| 3.7498e-01
# [stage2] epoch  1340 | step    6700 | mse_x_guided 0.4574 | |s(xg)| 8.0241e-01 | |s(y|xg)| 3.4658e-01
# [stage2] epoch  1360 | step    6800 | mse_x_guided 0.4471 | |s(xg)| 8.1199e-01 | |s(y|xg)| 3.3802e-01
# [stage2] epoch  1380 | step    6900 | mse_x_guided 0.4324 | |s(xg)| 8.2619e-01 | |s(y|xg)| 3.5650e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001400.pt
# [stage2] epoch  1400 | step    7000 | mse_x_guided 0.4424 | |s(xg)| 8.0774e-01 | |s(y|xg)| 3.3851e-01
# [stage2] epoch  1420 | step    7100 | mse_x_guided 0.4606 | |s(xg)| 8.1872e-01 | |s(y|xg)| 3.4120e-01
# [stage2] epoch  1440 | step    7200 | mse_x_guided 0.4458 | |s(xg)| 8.2593e-01 | |s(y|xg)| 3.5386e-01
# [stage2] epoch  1460 | step    7300 | mse_x_guided 0.4475 | |s(xg)| 8.4623e-01 | |s(y|xg)| 3.4609e-01
# [stage2] epoch  1480 | step    7400 | mse_x_guided 0.4799 | |s(xg)| 8.0279e-01 | |s(y|xg)| 3.3710e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001500.pt
# [stage2] epoch  1500 | step    7500 | mse_x_guided 0.4334 | |s(xg)| 8.2431e-01 | |s(y|xg)| 3.4530e-01
# [stage2] epoch  1520 | step    7600 | mse_x_guided 0.4382 | |s(xg)| 8.3712e-01 | |s(y|xg)| 3.5038e-01
# [stage2] epoch  1540 | step    7700 | mse_x_guided 0.4560 | |s(xg)| 8.0759e-01 | |s(y|xg)| 3.3341e-01
# [stage2] epoch  1560 | step    7800 | mse_x_guided 0.4353 | |s(xg)| 8.0577e-01 | |s(y|xg)| 3.5661e-01
# [stage2] epoch  1580 | step    7900 | mse_x_guided 0.4442 | |s(xg)| 8.3605e-01 | |s(y|xg)| 3.3795e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001600.pt
# [stage2] epoch  1600 | step    8000 | mse_x_guided 0.4309 | |s(xg)| 8.1912e-01 | |s(y|xg)| 3.4994e-01
# [stage2] epoch  1620 | step    8100 | mse_x_guided 0.4455 | |s(xg)| 8.2016e-01 | |s(y|xg)| 3.4294e-01
# [stage2] epoch  1640 | step    8200 | mse_x_guided 0.4603 | |s(xg)| 8.1880e-01 | |s(y|xg)| 3.4430e-01
# [stage2] epoch  1660 | step    8300 | mse_x_guided 0.4457 | |s(xg)| 8.3474e-01 | |s(y|xg)| 3.4208e-01
# [stage2] epoch  1680 | step    8400 | mse_x_guided 0.4707 | |s(xg)| 8.1008e-01 | |s(y|xg)| 3.4243e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001700.pt
# [stage2] epoch  1700 | step    8500 | mse_x_guided 0.4550 | |s(xg)| 8.2707e-01 | |s(y|xg)| 3.4240e-01
# [stage2] epoch  1720 | step    8600 | mse_x_guided 0.4579 | |s(xg)| 8.1014e-01 | |s(y|xg)| 3.4646e-01
# [stage2] epoch  1740 | step    8700 | mse_x_guided 0.4581 | |s(xg)| 8.2576e-01 | |s(y|xg)| 3.3474e-01
# [stage2] epoch  1760 | step    8800 | mse_x_guided 0.4680 | |s(xg)| 8.1427e-01 | |s(y|xg)| 3.5017e-01
# [stage2] epoch  1780 | step    8900 | mse_x_guided 0.4298 | |s(xg)| 8.3825e-01 | |s(y|xg)| 3.3400e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001800.pt
# [stage2] epoch  1800 | step    9000 | mse_x_guided 0.4562 | |s(xg)| 8.2614e-01 | |s(y|xg)| 3.3441e-01
# [stage2] epoch  1820 | step    9100 | mse_x_guided 0.4461 | |s(xg)| 8.1611e-01 | |s(y|xg)| 3.4269e-01
# [stage2] epoch  1840 | step    9200 | mse_x_guided 0.4381 | |s(xg)| 8.2856e-01 | |s(y|xg)| 3.3590e-01
# [stage2] epoch  1860 | step    9300 | mse_x_guided 0.4514 | |s(xg)| 8.3907e-01 | |s(y|xg)| 3.4442e-01
# [stage2] epoch  1880 | step    9400 | mse_x_guided 0.4446 | |s(xg)| 8.0391e-01 | |s(y|xg)| 3.5918e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_001900.pt
# [stage2] epoch  1900 | step    9500 | mse_x_guided 0.4509 | |s(xg)| 8.1751e-01 | |s(y|xg)| 3.4791e-01
# [stage2] epoch  1920 | step    9600 | mse_x_guided 0.4524 | |s(xg)| 8.0082e-01 | |s(y|xg)| 3.6001e-01
# [stage2] epoch  1940 | step    9700 | mse_x_guided 0.4519 | |s(xg)| 8.1807e-01 | |s(y|xg)| 3.6569e-01
# [stage2] epoch  1960 | step    9800 | mse_x_guided 0.4473 | |s(xg)| 8.1816e-01 | |s(y|xg)| 3.3378e-01
# [stage2] epoch  1980 | step    9900 | mse_x_guided 0.4528 | |s(xg)| 8.2235e-01 | |s(y|xg)| 3.4797e-01
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_002000.pt
# saved checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_002000.pt
# === Stage 2 complete ===

# %% [markdown]
# # load model

# %%
from b_models.hsami.recnet import RecNet
from b_models.hsami.hsami_alternate import HSAMI
from b_models.hsami.denoiser import Denoiser
from b_models.configs.hsami_config import HSAMI_Training_Config

checkpoint_path = "/mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_002000.pt"
checkpoint_dir = checkpoint_path.rsplit("/", 1)[0]
print(checkpoint_dir)
config = HSAMI_Training_Config()
config_path = checkpoint_dir + "/config.json"
config.load_from_json(config_path)

recnet = RecNet(config).to(device)

denoiser_x = Denoiser(
    config.input_dim, 
    hidden_dim=config.hidden_dim_x, 
    num_blocks=config.num_blocks_x, 
    time_dim=config.time_dim_x, 
    activation=config.activation
).to(device)

denoiser_y = Denoiser(
    config.latent_dim_y, 
    hidden_dim=config.hidden_dim_y, 
    num_blocks=config.num_blocks_y, 
    time_dim=config.time_dim_y, 
    activation=config.activation
).to(device)

hsami = HSAMI(
    recnet=recnet,
    denoiser_x=denoiser_x,
    denoiser_y=denoiser_y,
    args=config
).to(device)
# Out:
# /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313

# %% [markdown]
# # conditional generation

# %%
from a_datasets.ring.data_flat import WrappedPhaseRing, generate

dataset = WrappedPhaseRingFlat(
    n=config.n,
    m=config.m,
    kappa=config.kappa,
    r0=config.r0,
    sigma=config.sigma,
    seed=config.seed,
)

x, y = generate(n=config.n,
    m=config.m,
    kappa=config.kappa,
    r0=config.r0,
    sigma=config.sigma,
    seed=config.seed,
)

# get a sample from the dataset
example_datum = x[0].to(device)
example_datum.shape
# Out:
# torch.Size([2])

# %%
# load denoiser x only
# get the latest checkpoint from stage 1 (denoiser x only training)
from b_models.hsami.sequential_training_ring import load_stage_checkpoint

checkpoint_dir = checkpoint_path.rsplit("/", 2)[0]
run_name = checkpoint_path.rsplit("/", 2)[1]
stage = 1
load_stage_checkpoint(hsami, checkpoint_dir, run_name, stage, device)

# checkpoint = torch.load(checkpoint_path)
# hsami_state_dict = checkpoint["model_state_dict"]
# denoiser_x_state_dict = {k[11:]: v for k, v in hsami_state_dict.items() if "denoiser_x" in k}
# hsami.denoiser_x.load_state_dict(denoiser_x_state_dict)
# hsami.to(device).eval();
# Out:
# loaded checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage1_epoch_000500.pt
#   restored 40 tensors (prefixes: denoiser_x.)

# %%
samples = hsami.unconditional_sample(2000, denoiser_type="x")

# %%
# plot the example datum among the dataset
x_cpu = x.cpu().numpy()[:2000]
example_datum_cpu = example_datum.cpu().numpy()

fig, ax = plt.subplots(1, 2, figsize=(8, 6))
ax[0].scatter(x_cpu[:, 0], x_cpu[:, 1], alpha=0.3, s=20, label='Dataset Samples')
ax[0].set_title('dataset samples')
# now plot the generated sample as well
samples_cpu = samples.detach().cpu().numpy()
ax[1].scatter(samples_cpu[:, 0], samples_cpu[:, 1], color='green', label='Generated Sample', alpha=0.3, s=20)
ax[1].set_title('x denoiser generated samples')
# match axes
ax[0].set_xlim(x_cpu[:, 0].min() - 1, x_cpu[:, 0].max() + 1)
ax[0].set_ylim(x_cpu[:, 1].min() - 1, x_cpu[:, 1].max() + 1)
ax[1].set_xlim(x_cpu[:, 0].min() - 1, x_cpu[:, 0].max() + 1)
ax[1].set_ylim(x_cpu[:, 1].min() - 1, x_cpu[:, 1].max() + 1)
# set equal aspect ratio
plt.tight_layout()
ax[0].set_aspect('equal', adjustable='box')
ax[1].set_aspect('equal', adjustable='box')

# %% [markdown]
# # stage 2 as well

# %%
# load x denoiser and x->y recnet
checkpoint_dir = checkpoint_path.rsplit("/", 2)[0]
run_name = checkpoint_path.rsplit("/", 2)[1]
stage = 2
load_stage_checkpoint(hsami, checkpoint_dir, run_name, stage, device)
# Out:
# loaded checkpoint: /mnt/ceph/users/blyo1/projects/hdiva/c_training/hsami_checkpoints_ring/sequential_20260620_131313/stage2_epoch_002000.pt
#   restored 48 tensors (prefixes: denoiser_x., recnet.layers_x_to_y., recnet.head_y.)

# %%
# get a sample from the dataset
from a_datasets.ring.data_flat import WrappedPhaseRingFlat, generate

dataset = WrappedPhaseRingFlat(
    n=config.n,
    m=config.m,
    kappa=config.kappa,
    r0=config.r0,
    sigma=config.sigma,
    seed=config.seed,
)

x, y = generate(n=config.n,
    m=config.m,
    kappa=config.kappa,
    r0=config.r0,
    sigma=config.sigma,
    seed=config.seed,
)
example_datum = x[6].to(device)

stage2_samples = hsami.stage2_generation(1000, example_datum.unsqueeze(0))
stage2_samples.shape
# Out:
# torch.Size([1000, 2])

# %%
# plot the example datum among the dataset
x_cpu = x.cpu().numpy()[:2000]
example_datum_cpu = example_datum.cpu().numpy()

fig, ax = plt.subplots(1, 2, figsize=(8, 6))
ax[0].scatter(x_cpu[:, 0], x_cpu[:, 1], alpha=0.3, s=20, label='Dataset Samples')
ax[0].set_title('dataset samples')
ax[0].scatter(example_datum_cpu[0], example_datum_cpu[1], color='red', label='Example Datum', edgecolor='black', s=100)
# now plot the generated sample as well
stage2_samples_cpu = stage2_samples.detach().cpu().numpy()
ax[1].scatter(stage2_samples_cpu[:, 0], stage2_samples_cpu[:, 1], color='green', label='Generated Sample', alpha=0.3, s=20)
ax[1].set_title('y-cond x-denoiser samples')

ax[1].scatter(example_datum_cpu[0], example_datum_cpu[1], color='red', label='Example Datum', edgecolor='black', s=100)

# match axes
ax[0].set_xlim(x_cpu[:, 0].min() - 1, x_cpu[:, 0].max() + 1)
ax[0].set_ylim(x_cpu[:, 1].min() - 1, x_cpu[:, 1].max() + 1)
ax[1].set_xlim(x_cpu[:, 0].min() - 1, x_cpu[:, 0].max() + 1)
ax[1].set_ylim(x_cpu[:, 1].min() - 1, x_cpu[:, 1].max() + 1)
# set equal aspect ratio
plt.tight_layout()
ax[0].set_aspect('equal', adjustable='box')
ax[1].set_aspect('equal', adjustable='box')

# %% [markdown]
# measure the log likelihood of the red dot with respect to a point on the green sample
